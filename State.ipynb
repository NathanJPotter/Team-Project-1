# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import scipy.stats as st
#from scipy.stats import linregress
#from sklearn import linear_model
#import statsmodels.api as sm
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

# %%
#  data files
house_price_city = "Resources/house_price_city.csv"
births = "Resources/births_number.csv"

# %%
# Read the data
house_price =  pd.read_csv(house_price_city)
births = pd.read_csv(births)
# house_price["Births"] = np.nan
data_df = pd.merge(house_price, births, on=['Year','Location'])

# %%
data_df
# Out:
#      Year           Location   Type   Price  Births
# 0    2012     Greater Sydney  Urban  608130   66474
# 1    2012        Rest of NSW  Rural  346500   31583
# 2    2012  Greater Melbourne  Urban  487750   59997
# 3    2012        Rest of Vic  Rural  291000   17282
# 4    2012   Greater Brisbane  Urban  435000   31361
# ..    ...                ...    ...     ...     ...
# 107  2019         Rest of WA  Rural  324630    6621
# 108  2019     Greater Hobart  Urban  490000    2717
# 109  2019        Rest of Tas  Rural  320000    3018
# 110  2019     Greater Darwin  Urban  478500    2141
# 111  2019         Rest of NT  Rural  421630    1511
#
# [112 rows x 5 columns]

# %%
colors = {"Urban":"orchid","Rural":"lightgreen"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Type == "Urban"]
rural_set = data_df[data_df.Type == "Rural"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/250),
                       color=colors["Urban"],
                       label="Urban",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/250),
                       color=colors["Rural"],
                       label="Rural",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 1000000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Urban vs Rural")

plt.show()

# %%
scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Type == "Urban"]
rural_set = data_df[data_df.Type == "Rural"]

ax = urban_set.plot.scatter(x="Year",y="Births",
                       edgecolor='dimgrey',
                       s=(urban_set.Price/2500),
                       color=colors["Urban"],
                       label="Urban",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Births",
                       edgecolor='dimgrey',
                       s=(rural_set.Price/2500),
                       color=colors["Rural"],
                       label="Rural",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(1000, 100000, 5000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Urban vs Rural")

plt.show()

# %%
colors = {"Sydney":"skyblue","Rest of NSW":"lime"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Location == "Greater Sydney"]
rural_set = data_df[data_df.Location == "Rest of NSW"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/100),
                       color=colors["Sydney"],
                       label="Sydney",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/100),
                       color=colors["Rest of NSW"],
                       label="Rest of NSW",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 1100000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Sydney vs Rest of NSW")
ax.ticklabel_format(style='plain')
plt.savefig('saved_figure.png')
plt.show()

# %%
colors = {"Melbourne":"lightcoral","Rest of Vic":"dodgerblue"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Location == "Greater Melbourne"]
rural_set = data_df[data_df.Location == "Rest of Vic"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/100),
                       color=colors["Melbourne"],
                       label="Melbourne",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/100),
                       color=colors["Rest of Vic"],
                       label="Rest of Vic",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 1000000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Melbourne vs Rest of Victoria")
ax.ticklabel_format(style='plain')
plt.savefig('saved_figure.png')
plt.show()

# %%
colors = {"Brisbane":"fuchsia","Rest of Qld":"turquoise"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Location == "Greater Brisbane"]
rural_set = data_df[data_df.Location == "Rest of Qld"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/100),
                       color=colors["Brisbane"],
                       label="Brisbane",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/100),
                       color=colors["Rest of Qld"],
                       label="Rest of Qld",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 700000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Brisbane vs Rest of Queensland")
ax.ticklabel_format(style='plain')
plt.savefig('saved_figure.png')
plt.show()

# %%
colors = {"Adelaide":"darkorange","Rest of SA":"forestgreen"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Location == "Greater Adelaide"]
rural_set = data_df[data_df.Location == "Rest of SA"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/100),
                       color=colors["Adelaide"],
                       label="Adelaide",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/100),
                       color=colors["Rest of SA"],
                       label="Rest of SA",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 700000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Adelaide vs Rest of South Australia")
ax.ticklabel_format(style='plain')
plt.savefig('saved_figure.png')
plt.show()

# %%
colors = {"Perth":"darkviolet","Rest of WA":"violet"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Location == "Greater Perth"]
rural_set = data_df[data_df.Location == "Rest of WA"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/100),
                       color=colors["Perth"],
                       label="Perth",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/100),
                       color=colors["Rest of WA"],
                       label="Rest of WA",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 700000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Perth vs Rest of West Australia")
ax.ticklabel_format(style='plain')
plt.savefig('saved_figure.png')
plt.show()

# %%
colors = {"Hobart":"midnightblue","Rest of Tas":"red"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Location == "Greater Hobart"]
rural_set = data_df[data_df.Location == "Rest of Tas"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/100),
                       color=colors["Hobart"],
                       label="Hobart",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/100),
                       color=colors["Rest of Tas"],
                       label="Rest of Tas",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 700000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Hobart vs Rest of Tasmania")
ax.ticklabel_format(style='plain')
plt.savefig('saved_figure.png')
plt.show()

# %%
colors = {"Darwin":"gold","Rest of NT":"forestgreen"}
plt.style.use("seaborn")

scatter_plot_df = data_df[["Year","Price","Type"]]

urban_set = data_df[data_df.Location == "Greater Darwin"]
rural_set = data_df[data_df.Location == "Rest of NT"]

ax = urban_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(urban_set.Births/100),
                       color=colors["Darwin"],
                       label="Darwin",
                       linewidth = 1,)


rural_set.plot.scatter(x="Year",y="Price",
                       edgecolor='dimgrey',
                       s=(rural_set.Births/100),
                       color=colors["Rest of NT"],
                       label="Rest of NT",
                       linewidth = 1,
                       ax=ax)

plt.yticks(np.arange(200000, 700000, 50000))
plt.legend(title="Types")
plt.title("House Prices and Birth Rate - Darwin vs Rest of North Territory")
plt.savefig('saved_figure.png')
plt.show()
