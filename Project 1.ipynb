# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read in csv
birth_path = 'abs_ births_StatAreas_level4_2012-2019_Table 1.1.csv'
birth_data_df = pd.read_csv(birth_path)

birth_data_df.head(20)
# Out:
#                       Australian Bureau of Statistics  \
# 0                   33010DO001 Births, Australia 2019
# 1   Released at 11.30am (Canberra time) Wed 9 Dec ...
# 2   Table 1.1 Births, Summary, Statistical Areas L...
# 3                                                 NaN
# 4                                                 NaN
# 5                            Place of Usual Residence
# 6                                      2016 ASGS code
# 7                                                   1
# 8                                                 102
# 9                                                 115
# 10                                                116
# 11                                                117
# 12                                                118
# 13                                                119
# 14                                                120
# 15                                                121
# ...
