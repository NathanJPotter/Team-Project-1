# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read in csv
birth_path = 'Birth_Rate_Data_Project_stater.csv'
birth_data_df = pd.read_csv(birth_path)

birth_data_df
# Out:
#                             Unnamed: 0                           2012  \
# 0                                  NaN                            NaN
# 1                                  NaN  Estimated resident population
# 2                                  NaN                        persons
# 3                       Greater Sydney                      4,677,196
# 4                          Rest of NSW                      2,627,048
# 5                Total New South Wales                      7,304,244
# 6                    Greater Melbourne                      4,265,843
# 7                         Rest of Vic.                      1,385,248
# 8                       Total Victoria                      5,651,091
# 9                     Greater Brisbane                      2,196,288
# 10                         Rest of Qld                      2,372,399
# 11                    Total Queensland                      4,568,687
# ...
