# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read in csv
birth_path = 'abs_table 6.1_2015.csv'
birth_data_df = pd.read_csv(birth_path)

birth_data_df.head(20)
# Out:
#                       Australian Bureau of Statistics    Unnamed: 1  \
# 0                      3301.0 Births, Australia, 2015           NaN
# 1   Released at 11:30 am (Canberra time) Tues 8 No...           NaN
# 2   Table 6.1 Births, Country of birth of mother–2015           NaN
# 3                                                 NaN           NaN
# 4                                                 NaN  Total births
# 5                          Country of birth of mother           no.
# 6                                               Total      -305,377
# 7                                 Total overseas-born       104,900
# 8                              Oceania and Antarctica       212,629
# 9                                           Australia       200,157
# 10                                               Fiji         1,061
# 11                                        New Zealand         9,546
# 12                                   Papua New Guinea           477
# ...
